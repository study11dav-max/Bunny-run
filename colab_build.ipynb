# %% [markdown]
# # 🐰 BunnyBot APK Builder
# Run this notebook in Google Colab to build your APK.
#
# ### Instructions
# 1. Upload your project files (main.py, buildozer.spec, core/, ui/, templates/) to the Colab runtime.
# 2. Run the cells below in order.

# %%
# !pip install buildozer cython==0.29.33

# %%
# !sudo apt-get install -y \
    python3-pip \
    build-essential \
    git \
    python3 \
    python3-dev \
    ffmpeg \
    libsdl2-dev \
    libsdl2-image-dev \
    libsdl2-mixer-dev \
    libsdl2-ttf-dev \
    libportmidi-dev \
    libswscale-dev \
    libavformat-dev \
    libavcodec-dev \
    zlib1g-dev

# %%
# !buildozer android debug

# %% [markdown]
# ### ✅ Build Complete
# Check the `bin/` directory in the file explorer on the left to download your APK.
